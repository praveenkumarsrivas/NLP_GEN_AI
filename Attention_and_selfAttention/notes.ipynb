# %% [markdown]
# ## Attention
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Self attention
# ![](https://s1.ax1x.com/2018/12/06/F126xI.gif)

# %% [markdown]
# ![image.png](attachment:image.png)
