# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/1*kwJNcK2SD5LYLhluGVGhiQ.png,"b")

# %% [markdown]
# ![image.png](attachment:image.png)
